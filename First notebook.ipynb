# %%
print("Hello world")

# %%
def even():
    for i in range(0,10):
        if i % 2 == 0:
            print(i)
even()

# %% [markdown]
# # First notebook change separately with second notebook branch change
